# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

class CoupangScraper:
    def __init__(self, query):
        self.query = query
        self.url = "https://www.coupang.com/np/search?component=&q=" + query + "&channel=user"
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
            "Accept-Language": "ko-KR,ko;q=0.8,en-US;q=0.5,en;q=0.3"
        }
        self.products = []

    def scrape(self):
        response = requests.get(self.url, headers=self.headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        li_tags = soup.find_all('li', attrs={'class':'search-product'})

        for li in li_tags:
            name = li.find('div', class_='name').text
            price = li.find('strong', class_='price-value').text
            link = "https://www.coupang.com" + li.find('a', class_='search-product-link')['href']
            self.products.append((name, price, link))

    def to_dataframe(self):
        df = pd.DataFrame(self.products, columns=['Product_Name', 'Price', 'Product_Link'])
        df['Price'] = df['Price'].str.replace(',', '').astype(int)
        return df

# %%
# 사용 예시
query = '할인'
scraper = CoupangScraper(query)
scraper.scrape()
df = scraper.to_dataframe()

# %%
# CSV 파일로 저장
df.to_csv('Coupang_products.csv', index=False)

# %%
df.sort_values(by='Price')
# Out:
#                                          Product_Name  Price  \
# 15  \n                                            ...   1350
# 14  \n                                            ...   2970
# 2                                  해태제과 에이스, 364g, 1개   3180
# 5                                농심 순하군 안성탕면 125g, 5개   3380
# 32                                   돌 바나나, 1.2kg, 1개   3660
# 1                                          농심 신라면, 5개   3900
# 35                                돌 스위티오 바나나, 1kg, 1개   4040
# 22                          델몬트 필리핀 바나나, 1.4kg 내외, 1개   4270
# 24                    켈로그 오곡으로 만든 첵스 초코 시리얼, 570g, 1개   5250
# 30                              오리온초코파이 12p, 468g, 2개   7170
# 8                           켈로그 콘푸로스트 시리얼, 1.32kg, 1개   8280
# 3                                  해태제과 오예스, 900g, 1개   8790
# 33                            곡물그대로21 크리스피롤, 650g, 1개   9110
# 6                                  오리온 초코파이, 468g, 3개  10720
# 28    [시즌오프 할인] 융털 9부 레깅스 2color [국내생산 프리미엄] 빅사이즈 레깅스  10900
# 27                             광천김 참 재래도시락 김, 5g, 64개  11990
# 16  프링글스 버라이어티팩 오리지널 110g x 2p + 양파맛 110g x 2p + 매...  12460
# 25                         셰프초이스 춘천식닭갈비 (냉장), 1kg, 1개  12490
# 20  [시즌오프 할인] 옆라인 융털 레깅스 팬츠 [국내생산 프리미엄] FREE~4XL 겨...  12900
# 36        특가할인! 따뜻한 겨울필수템~여성 후드 머플러 바라클라바 목도리 넥워머 곰돌이  12900
# 26          [특가할인] T/C 허리 끈 조절 스크럽복 실습복 바지 하의 SC복 수술복  12900
# 7                                     제주 삼다수, 2L, 12개  12960
# 34                      다향오리 1등급 훈제 오리 슬라이스, 600g, 1개  13590
# 23                             오리온 포카칩 오리지널, 66g, 12개  14010
# 38              푸드랩플러스 미국산 돌돌말이 대패 우삼겹 (냉동), 800g, 1개  14070
# 18                                  구운감자 스낵, 24g, 30개  15000
# 13  \n                                            ...  16320
# 9                    맥심 화이트 골드 커피믹스, 11.7g, 160개입, 1개  18910
